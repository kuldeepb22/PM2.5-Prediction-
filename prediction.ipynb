# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (1.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.22.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.3.1)
# [notice] A new release of pip is available: 23.0 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns
  


from sklearn.model_selection import train_test_split  
from sklearn.preprocessing import StandardScaler, OneHotEncoder  


from sklearn.linear_model import LinearRegression  

from sklearn.metrics import mean_absolute_error  

from keras.models import Sequential  
from keras.layers import Dense

# %%
data = pd.read_csv('sensor.csv')
data = data[288:]
data
# Out:
#             Timestamp  IITK01  IITK02      IITK03  IITK04  IITK06  IITK07  \
# 288  13-11-2022 00:00     NaN   92.75   97.750000  107.25  121.75  142.25
# 289  13-11-2022 01:00     NaN   93.00  101.750000  107.00  117.75  139.50
# 290  13-11-2022 02:00     NaN   94.50   86.666667  109.00  117.25  136.25
# 291  13-11-2022 03:00     NaN   94.50   93.500000  109.25  117.50  145.00
# 292  13-11-2022 04:00     NaN   94.50   89.250000  109.00  115.75  156.00
# ..                ...     ...     ...         ...     ...     ...     ...
# 715  30-11-2022 19:00     NaN  111.50  181.000000  154.50   92.75  271.75
# 716  30-11-2022 20:00     NaN  115.50  205.250000  173.75  117.50  300.25
# 717  30-11-2022 21:00     NaN  112.50  225.750000  178.50  134.75  343.75
# 718  30-11-2022 22:00     NaN  125.25  265.750000  169.25  143.50  327.00
# 719  30-11-2022 23:00     NaN  114.00  224.000000  158.75  146.25  240.50
#
#      IITK08  IITK10  IITK11  ...  IITK15  IITK17  IITK18  IITK19  IITK20  \
# 288     NaN   93.50   96.50  ...     NaN  102.50     NaN   75.75     NaN
# 289     NaN   91.25   98.25  ...     NaN  107.75     NaN   72.00     NaN
# 290     NaN   90.25  101.25  ...     NaN  106.75     NaN   72.00     NaN
# 291     NaN   95.00  111.00  ...     NaN  107.50     NaN   76.75     NaN
# 292     NaN   97.75  107.50  ...     NaN  104.00     NaN   81.00     NaN
# ..      ...     ...     ...  ...     ...     ...     ...     ...     ...
# 715     NaN  102.50  200.25  ...  156.75  142.25  199.25  121.25  157.00
# 716     NaN  117.50  213.50  ...  170.25  150.50  208.00  146.50  203.75
# 717     NaN  122.50  236.25  ...  213.00  142.50  218.50  162.75  160.50
# 718     NaN  120.50  224.50  ...  286.00  144.00  235.00  187.50  137.00
# 719     NaN  100.50  173.25  ...  273.25  153.25  189.50  189.50  131.75
#
#      IITK21  IITK22  IITK23      IITK24  IITK25
# 288  119.00   87.75  149.00  176.500000   90.75
# 289  105.50   92.00  154.50  152.000000   89.50
# 290  112.25   97.00  150.25  150.000000   89.75
# 291  128.75  102.50  151.00  163.500000   95.00
# 292  127.50  103.75  152.00  154.250000   93.50
# ..      ...     ...     ...         ...     ...
# 715     NaN     NaN  145.25  123.666667  120.25
# 716  281.00     NaN  174.00  121.500000  129.25
# 717  288.25     NaN  183.50  128.000000  131.00
# 718  248.00     NaN  170.50  128.500000  125.25
# 719  240.50     NaN  162.75  130.250000  136.75
#
# [432 rows x 23 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 288 to 719
# Data columns (total 23 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  432 non-null    object
#  1   IITK01     0 non-null      float64
#  2   IITK02     428 non-null    float64
#  3   IITK03     417 non-null    float64
#  4   IITK04     417 non-null    float64
#  5   IITK06     405 non-null    float64
#  6   IITK07     398 non-null    float64
#  7   IITK08     0 non-null      float64
#  8   IITK10     411 non-null    float64
#  9   IITK11     409 non-null    float64
#  10  IITK12     427 non-null    float64
#  11  IITK13     375 non-null    float64
#  12  IITK14     343 non-null    float64
#  13  IITK15     257 non-null    float64
#  14  IITK17     377 non-null    float64
#  15  IITK18     180 non-null    float64
#  16  IITK19     253 non-null    float64
#  17  IITK20     197 non-null    float64
#  18  IITK21     395 non-null    float64
#  19  IITK22     379 non-null    float64
#  20  IITK23     408 non-null    float64
#  21  IITK24     384 non-null    float64
#  22  IITK25     400 non-null    float64
# dtypes: float64(22), object(1)
# memory usage: 77.8+ KB

# %%
data.describe()
# Out:
#        IITK01      IITK02      IITK03      IITK04      IITK06      IITK07  \
# count     0.0  428.000000  417.000000  417.000000  405.000000  398.000000
# mean      NaN   85.769665  119.384093  101.419864   89.756996  129.783291
# std       NaN   35.712012   63.863700   50.388978   33.821033   61.086186
# min       NaN   23.500000   25.000000   24.000000   21.500000   36.500000
# 25%       NaN   58.500000   68.500000   61.500000   58.500000   82.875000
# 50%       NaN   86.500000  106.250000   96.750000   93.750000  124.250000
# 75%       NaN  108.312500  152.250000  133.000000  117.250000  154.187500
# max       NaN  335.750000  362.500000  325.000000  173.500000  389.750000
#
#        IITK08      IITK10      IITK11      IITK12  ...      IITK15  \
# count     0.0  411.000000  409.000000  427.000000  ...  257.000000
# mean      NaN   84.348946  113.034026   92.869438  ...   95.506485
# std       NaN   32.585235   51.386502   42.957121  ...   47.037757
# min       NaN   24.750000   31.000000   24.250000  ...   26.750000
# 25%       NaN   58.000000   74.250000   57.750000  ...   58.000000
# 50%       NaN   86.000000  105.250000   89.500000  ...   89.000000
# 75%       NaN  103.000000  145.000000  120.375000  ...  122.000000
# max       NaN  202.750000  283.750000  293.500000  ...  302.500000
#
#            IITK17      IITK18      IITK19      IITK20      IITK21      IITK22  \
# count  377.000000  180.000000  253.000000  197.000000  395.000000  379.000000
# mean   104.258842  112.754167   80.234519   88.949662  151.670253   96.710202
# std     43.686006   57.029974   35.041673   41.863029   67.843403   50.386408
# min     30.000000   24.750000   22.250000   22.250000   37.250000   21.500000
# 25%     67.000000   67.250000   52.500000   57.250000  102.000000   57.125000
# 50%    102.500000  106.000000   77.750000   81.750000  145.500000   87.750000
# 75%    137.000000  151.000000   97.000000  112.000000  185.500000  121.875000
# max    278.750000  268.250000  189.500000  247.000000  411.000000  286.250000
#
#            IITK23      IITK24      IITK25
# count  408.000000  384.000000  400.000000
# mean   125.262255  108.163628   83.677917
# std     49.983507   38.095009   29.989503
# min     30.000000   28.000000   24.750000
# 25%     81.187500   76.500000   57.437500
# 50%    127.125000  108.875000   84.500000
# 75%    156.500000  132.562500  105.437500
# max    359.750000  221.500000  166.750000
#
# [8 rows x 22 columns]

# %%
props = pd.read_csv('location.csv')
props
# Out:
#     S.No Sensor No.   Serial No.                                  Location  \
# 0      1    IITK-01  81432131001                           Transport Nagar
# 1      2    IITK-02  81432131016                                Jankipuram
# 2      3    IITK-03  81432131006                               Nishat Ganj
# 3      4    IITK-04  81432130003                                   Aliganj
# 4      5    IITK-06  81432131013                                    Kakori
# 5      6    IITK-07  81432130005                         Rajendra Nagar-II
# 6      7    IITK-08  81432131007                                  Charbagh
# 7      8    IITK-10  81432131005                                Husainabad
# 8      9    IITK-11  81432131015                           IITR-Hazratganj
# 9     10    IITK-12  81432131004                                 Mahanagar
# 10    11    IITK-13  81432131012                          Vrindavan Yojana
# 11    12    IITK-14  81432130004  B R Ambedkar University, Lucknow - UPPCB
# 12    13    IITK-15  81432131011                                  Aminabad
# 13    14     IITK16  81432130010    Kukrail Picnic Spot-1, Lucknow - UPPCB
# 14    15    IITK-17  81432131014              Gomti Nagar, Lucknow - UPPCB
# 15    16    IITK-18  81432130008                        Lucknow Cantonment
# 16    17    IITK-19  81432131009                               Vipul Khand
# 17    18    IITK-20  81432131002                                   Dubagga
# 18    19    IITK-21  81432147001                                 Arjunganj
# 19    20     IITK22  81432147004                               Anand Nagar
# 20    21     IITK23  81432147008                           CMS_Kanpur Road
# 21    22     IITK24  81432147023                                 Piparsand
# 22    23     IITK25  81432147033                       Kukrail_later_uppcb
# 23    24     IITK26  81435147034                             Talkatora_BPS
# 24    25     IITK28  81435147036                                  Telibagh
#
#      Latitude  Longitude Date of Installation
# 0   26.779170  80.885063           13-12-2021
# 1   26.915201  80.942171           11-12-2021
# 2   26.865388  80.954702           11-12-2021
# 3   26.901733  80.951876           11-12-2021
# 4   26.519931  80.235688           20-12-2021
# 5   26.904335  80.765377           23-12-2021
# 6   26.837670  80.934498           23-12-2021
# 7   26.870196  80.904134           23-12-2021
# 8   26.859402  80.930709           25-12-2021
# 9   26.882188  80.950551           13-12-2021
# 10  26.780629  80.955885           15-12-2021
# 11  26.766433  80.927299           25-12-2021
# 12  26.848328  80.923331           13-12-2021
# 13  26.907270  80.985200           17-12-2021
# 14  26.864693  81.004908           15-12-2021
# 15  26.820903  80.948628           13-12-2021
# 16  26.846359  80.982456           15-12-2021
# 17  26.854684  80.859587           25-12-2021
# 18  26.807260  80.998110           27-04-2022
# 19  26.821692  80.920193           26-02-2022
# 20  26.789759  80.894295           08-03-2022
# 21  26.746663  80.818573           30-04-2022
# 22  26.907270  80.985200           30-03-2022
# 23  26.832976  80.900473           07-05-2022
# 24  26.790170  80.958620           27-04-2022

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'], format='%d-%m-%Y %H:%M')
data['Timestamp']
# Out:
# 288   2022-11-13 00:00:00
# 289   2022-11-13 01:00:00
# 290   2022-11-13 02:00:00
# 291   2022-11-13 03:00:00
# 292   2022-11-13 04:00:00
#               ...
# 715   2022-11-30 19:00:00
# 716   2022-11-30 20:00:00
# 717   2022-11-30 21:00:00
# 718   2022-11-30 22:00:00
# 719   2022-11-30 23:00:00
# Name: Timestamp, Length: 432, dtype: datetime64[ns]

# %%
data['PM_Day'] = data['Timestamp'].dt.day
data['PM_Hour'] = data['Timestamp'].dt.hour
data['PM_Month'] = data['Timestamp'].dt.month
data
# Out:
#               Timestamp  IITK01  IITK02      IITK03  IITK04  IITK06  IITK07  \
# 288 2022-11-13 00:00:00     NaN   92.75   97.750000  107.25  121.75  142.25
# 289 2022-11-13 01:00:00     NaN   93.00  101.750000  107.00  117.75  139.50
# 290 2022-11-13 02:00:00     NaN   94.50   86.666667  109.00  117.25  136.25
# 291 2022-11-13 03:00:00     NaN   94.50   93.500000  109.25  117.50  145.00
# 292 2022-11-13 04:00:00     NaN   94.50   89.250000  109.00  115.75  156.00
# ..                  ...     ...     ...         ...     ...     ...     ...
# 715 2022-11-30 19:00:00     NaN  111.50  181.000000  154.50   92.75  271.75
# 716 2022-11-30 20:00:00     NaN  115.50  205.250000  173.75  117.50  300.25
# 717 2022-11-30 21:00:00     NaN  112.50  225.750000  178.50  134.75  343.75
# 718 2022-11-30 22:00:00     NaN  125.25  265.750000  169.25  143.50  327.00
# 719 2022-11-30 23:00:00     NaN  114.00  224.000000  158.75  146.25  240.50
#
#      IITK08  IITK10  IITK11  ...  IITK19  IITK20  IITK21  IITK22  IITK23  \
# 288     NaN   93.50   96.50  ...   75.75     NaN  119.00   87.75  149.00
# 289     NaN   91.25   98.25  ...   72.00     NaN  105.50   92.00  154.50
# 290     NaN   90.25  101.25  ...   72.00     NaN  112.25   97.00  150.25
# 291     NaN   95.00  111.00  ...   76.75     NaN  128.75  102.50  151.00
# 292     NaN   97.75  107.50  ...   81.00     NaN  127.50  103.75  152.00
# ..      ...     ...     ...  ...     ...     ...     ...     ...     ...
# 715     NaN  102.50  200.25  ...  121.25  157.00     NaN     NaN  145.25
# 716     NaN  117.50  213.50  ...  146.50  203.75  281.00     NaN  174.00
# 717     NaN  122.50  236.25  ...  162.75  160.50  288.25     NaN  183.50
# 718     NaN  120.50  224.50  ...  187.50  137.00  248.00     NaN  170.50
# 719     NaN  100.50  173.25  ...  189.50  131.75  240.50     NaN  162.75
#
#          IITK24  IITK25  PM_Day  PM_Hour  PM_Month
# 288  176.500000   90.75      13        0        11
# 289  152.000000   89.50      13        1        11
# 290  150.000000   89.75      13        2        11
# 291  163.500000   95.00      13        3        11
# 292  154.250000   93.50      13        4        11
# ..          ...     ...     ...      ...       ...
# 715  123.666667  120.25      30       19        11
# 716  121.500000  129.25      30       20        11
# 717  128.000000  131.00      30       21        11
# 718  128.500000  125.25      30       22        11
# 719  130.250000  136.75      30       23        11
#
# [432 rows x 26 columns]

# %%
props = props.set_index('Sensor No.')
props
# Out:
#             S.No   Serial No.                                  Location  \
# Sensor No.
# IITK-01        1  81432131001                           Transport Nagar
# IITK-02        2  81432131016                                Jankipuram
# IITK-03        3  81432131006                               Nishat Ganj
# IITK-04        4  81432130003                                   Aliganj
# IITK-06        5  81432131013                                    Kakori
# IITK-07        6  81432130005                         Rajendra Nagar-II
# IITK-08        7  81432131007                                  Charbagh
# IITK-10        8  81432131005                                Husainabad
# IITK-11        9  81432131015                           IITR-Hazratganj
# IITK-12       10  81432131004                                 Mahanagar
# IITK-13       11  81432131012                          Vrindavan Yojana
# IITK-14       12  81432130004  B R Ambedkar University, Lucknow - UPPCB
# IITK-15       13  81432131011                                  Aminabad
# IITK16        14  81432130010    Kukrail Picnic Spot-1, Lucknow - UPPCB
# IITK-17       15  81432131014              Gomti Nagar, Lucknow - UPPCB
# IITK-18       16  81432130008                        Lucknow Cantonment
# IITK-19       17  81432131009                               Vipul Khand
# IITK-20       18  81432131002                                   Dubagga
# IITK-21       19  81432147001                                 Arjunganj
# IITK22        20  81432147004                               Anand Nagar
# IITK23        21  81432147008                           CMS_Kanpur Road
# IITK24        22  81432147023                                 Piparsand
# IITK25        23  81432147033                       Kukrail_later_uppcb
# IITK26        24  81435147034                             Talkatora_BPS
# IITK28        25  81435147036                                  Telibagh
#
#              Latitude  Longitude Date of Installation
# Sensor No.
# IITK-01     26.779170  80.885063           13-12-2021
# IITK-02     26.915201  80.942171           11-12-2021
# IITK-03     26.865388  80.954702           11-12-2021
# IITK-04     26.901733  80.951876           11-12-2021
# IITK-06     26.519931  80.235688           20-12-2021
# IITK-07     26.904335  80.765377           23-12-2021
# IITK-08     26.837670  80.934498           23-12-2021
# IITK-10     26.870196  80.904134           23-12-2021
# IITK-11     26.859402  80.930709           25-12-2021
# IITK-12     26.882188  80.950551           13-12-2021
# IITK-13     26.780629  80.955885           15-12-2021
# IITK-14     26.766433  80.927299           25-12-2021
# IITK-15     26.848328  80.923331           13-12-2021
# IITK16      26.907270  80.985200           17-12-2021
# IITK-17     26.864693  81.004908           15-12-2021
# IITK-18     26.820903  80.948628           13-12-2021
# IITK-19     26.846359  80.982456           15-12-2021
# IITK-20     26.854684  80.859587           25-12-2021
# IITK-21     26.807260  80.998110           27-04-2022
# IITK22      26.821692  80.920193           26-02-2022
# IITK23      26.789759  80.894295           08-03-2022
# IITK24      26.746663  80.818573           30-04-2022
# IITK25      26.907270  80.985200           30-03-2022
# IITK26      26.832976  80.900473           07-05-2022
# IITK28      26.790170  80.958620           27-04-2022

# %%
# assigning the values of the sensor no. column which is now index for data_props dataframe
props.index = ['IITK01', 'IITK02', 'IITK03', 'IITK04', 'IITK06', 'IITK07',
       'IITK08', 'IITK10', 'IITK11', 'IITK12', 'IITK13', 'IITK14',
       'IITK15', 'IITK16', 'IITK17', 'IITK18', 'IITK19', 'IITK20',
       'IITK21', 'IITK22', 'IITK23', 'IITK24', 'IITK25', 'IITK26', 'IITK28']
props.index
# Out:
# Index(['IITK01', 'IITK02', 'IITK03', 'IITK04', 'IITK06', 'IITK07', 'IITK08',
#        'IITK10', 'IITK11', 'IITK12', 'IITK13', 'IITK14', 'IITK15', 'IITK16',
#        'IITK17', 'IITK18', 'IITK19', 'IITK20', 'IITK21', 'IITK22', 'IITK23',
#        'IITK24', 'IITK25', 'IITK26', 'IITK28'],
#       dtype='object')

# %%
# Showing all rows and colum 1 to 28 of data's dataframe.
sensor_df = data.iloc[:,1:28]
sensor_df
# Out:
#      IITK01  IITK02      IITK03  IITK04  IITK06  IITK07  IITK08  IITK10  \
# 288     NaN   92.75   97.750000  107.25  121.75  142.25     NaN   93.50
# 289     NaN   93.00  101.750000  107.00  117.75  139.50     NaN   91.25
# 290     NaN   94.50   86.666667  109.00  117.25  136.25     NaN   90.25
# 291     NaN   94.50   93.500000  109.25  117.50  145.00     NaN   95.00
# 292     NaN   94.50   89.250000  109.00  115.75  156.00     NaN   97.75
# ..      ...     ...         ...     ...     ...     ...     ...     ...
# 715     NaN  111.50  181.000000  154.50   92.75  271.75     NaN  102.50
# 716     NaN  115.50  205.250000  173.75  117.50  300.25     NaN  117.50
# 717     NaN  112.50  225.750000  178.50  134.75  343.75     NaN  122.50
# 718     NaN  125.25  265.750000  169.25  143.50  327.00     NaN  120.50
# 719     NaN  114.00  224.000000  158.75  146.25  240.50     NaN  100.50
#
#      IITK11  IITK12  ...  IITK19  IITK20  IITK21  IITK22  IITK23      IITK24  \
# 288   96.50   97.75  ...   75.75     NaN  119.00   87.75  149.00  176.500000
# 289   98.25  100.75  ...   72.00     NaN  105.50   92.00  154.50  152.000000
# 290  101.25   94.75  ...   72.00     NaN  112.25   97.00  150.25  150.000000
# 291  111.00   94.75  ...   76.75     NaN  128.75  102.50  151.00  163.500000
# 292  107.50   91.50  ...   81.00     NaN  127.50  103.75  152.00  154.250000
# ..      ...     ...  ...     ...     ...     ...     ...     ...         ...
# 715  200.25  131.25  ...  121.25  157.00     NaN     NaN  145.25  123.666667
# 716  213.50  146.00  ...  146.50  203.75  281.00     NaN  174.00  121.500000
# 717  236.25  151.00  ...  162.75  160.50  288.25     NaN  183.50  128.000000
# 718  224.50  140.75  ...  187.50  137.00  248.00     NaN  170.50  128.500000
# 719  173.25  118.50  ...  189.50  131.75  240.50     NaN  162.75  130.250000
#
#      IITK25  PM_Day  PM_Hour  PM_Month
# 288   90.75      13        0        11
# 289   89.50      13        1        11
# 290   89.75      13        2        11
# 291   95.00      13        3        11
# 292   93.50      13        4        11
# ..      ...     ...      ...       ...
# 715  120.25      30       19        11
# 716  129.25      30       20        11
# 717  131.00      30       21        11
# 718  125.25      30       22        11
# 719  136.75      30       23        11
#
# [432 rows x 25 columns]

# %% [markdown]
# Motive: Reshape the DataFrame using `melt` function
# `id_vars=['PM_Day', 'PM_Hour', 'PM_Month']`: These are the columns that will be retained as identifiers in the melted DataFrame
# `value_vars=sensor_df.columns[:72]`: These are the columns to be melted (sensor readings columns)
# `var_name='Sensor'`: This will be the new column name that will contain the sensor names
# `value_name='Sensor_reading'`: This will be the new column name that will contain the sensor readings

# %%
# Converting rows of sensor names IITK01,IITK02... to a single column mapped with their individual sensors.
melted_sensor_df = sensor_df.melt(id_vars=['PM_Day', 'PM_Hour', 'PM_Month'],
                    value_vars=sensor_df.columns[:72],
                    var_name='Sensor',
                    value_name='Sensor_reading')
melted_sensor_df
# Out:
#       PM_Day  PM_Hour  PM_Month  Sensor  Sensor_reading
# 0         13        0        11  IITK01             NaN
# 1         13        1        11  IITK01             NaN
# 2         13        2        11  IITK01             NaN
# 3         13        3        11  IITK01             NaN
# 4         13        4        11  IITK01             NaN
# ...      ...      ...       ...     ...             ...
# 9499      30       19        11  IITK25          120.25
# 9500      30       20        11  IITK25          129.25
# 9501      30       21        11  IITK25          131.00
# 9502      30       22        11  IITK25          125.25
# 9503      30       23        11  IITK25          136.75
#
# [9504 rows x 5 columns]

# %% [markdown]
# Now we have two dataframe `melted_sensor_df` and `data_props` , where `melted_sensor_df` conatins sensor data at each hour mapped with their individual sensor names and `data_props` dataframe contains properties of sensors.
# We have to merge these dataframes to get additional values in a single dataframe.
#
# Merging the `melted_sensor_df` DataFrame with the `data_props`
# 1. DataFrame based on the 'Sensor' column as the left key and the index of `data_props` as the right key.
# 2. As we do in SQL, the 'left' join type is used, which means that all rows from the left DataFrame (`melted_sensor_df`) will be included in the result, and only matching rows from the right DataFrame (`data_props`) will be included.

# %%
final_df = melted_sensor_df.merge(props,left_on='Sensor', right_index=True, how='left')
final_df
# Out:
#       PM_Day  PM_Hour  PM_Month  Sensor  Sensor_reading  S.No   Serial No.  \
# 0         13        0        11  IITK01             NaN     1  81432131001
# 1         13        1        11  IITK01             NaN     1  81432131001
# 2         13        2        11  IITK01             NaN     1  81432131001
# 3         13        3        11  IITK01             NaN     1  81432131001
# 4         13        4        11  IITK01             NaN     1  81432131001
# ...      ...      ...       ...     ...             ...   ...          ...
# 9499      30       19        11  IITK25          120.25    23  81432147033
# 9500      30       20        11  IITK25          129.25    23  81432147033
# 9501      30       21        11  IITK25          131.00    23  81432147033
# 9502      30       22        11  IITK25          125.25    23  81432147033
# 9503      30       23        11  IITK25          136.75    23  81432147033
#
#                  Location  Latitude  Longitude Date of Installation
# 0         Transport Nagar  26.77917  80.885063           13-12-2021
# 1         Transport Nagar  26.77917  80.885063           13-12-2021
# 2         Transport Nagar  26.77917  80.885063           13-12-2021
# 3         Transport Nagar  26.77917  80.885063           13-12-2021
# 4         Transport Nagar  26.77917  80.885063           13-12-2021
# ...                   ...       ...        ...                  ...
# 9499  Kukrail_later_uppcb  26.90727  80.985200           30-03-2022
# 9500  Kukrail_later_uppcb  26.90727  80.985200           30-03-2022
# 9501  Kukrail_later_uppcb  26.90727  80.985200           30-03-2022
# 9502  Kukrail_later_uppcb  26.90727  80.985200           30-03-2022
# 9503  Kukrail_later_uppcb  26.90727  80.985200           30-03-2022
#
# [9504 rows x 11 columns]

# %%
final_df['Date of Installation'] = pd.to_datetime(final_df['Date of Installation'])
final_df
# Out:
#       PM_Day  PM_Hour  PM_Month  Sensor  Sensor_reading  S.No   Serial No.  \
# 0         13        0        11  IITK01             NaN     1  81432131001
# 1         13        1        11  IITK01             NaN     1  81432131001
# 2         13        2        11  IITK01             NaN     1  81432131001
# 3         13        3        11  IITK01             NaN     1  81432131001
# 4         13        4        11  IITK01             NaN     1  81432131001
# ...      ...      ...       ...     ...             ...   ...          ...
# 9499      30       19        11  IITK25          120.25    23  81432147033
# 9500      30       20        11  IITK25          129.25    23  81432147033
# 9501      30       21        11  IITK25          131.00    23  81432147033
# 9502      30       22        11  IITK25          125.25    23  81432147033
# 9503      30       23        11  IITK25          136.75    23  81432147033
#
#                  Location  Latitude  Longitude Date of Installation
# 0         Transport Nagar  26.77917  80.885063           2021-12-13
# 1         Transport Nagar  26.77917  80.885063           2021-12-13
# 2         Transport Nagar  26.77917  80.885063           2021-12-13
# 3         Transport Nagar  26.77917  80.885063           2021-12-13
# 4         Transport Nagar  26.77917  80.885063           2021-12-13
# ...                   ...       ...        ...                  ...
# 9499  Kukrail_later_uppcb  26.90727  80.985200           2022-03-30
# 9500  Kukrail_later_uppcb  26.90727  80.985200           2022-03-30
# 9501  Kukrail_later_uppcb  26.90727  80.985200           2022-03-30
# 9502  Kukrail_later_uppcb  26.90727  80.985200           2022-03-30
# 9503  Kukrail_later_uppcb  26.90727  80.985200           2022-03-30
#
# [9504 rows x 11 columns]

# %% [markdown]
# ###### Calculate the time difference (in months) between the current date and the 'Date of Installation' for each row.
# 1. `pd.to_datetime('today')` gives the current date and time as a pandas Timestamp.
# 2. `(pd.to_datetime('today') - final_df['Date of Installation'])` calculates the time difference (timedelta) between the current date and each 'Date of Installation'.
# 3. The result of the timedelta division by `np.timedelta64(1, 'M')` converts the time difference to months. `np.timedelta64(1, 'M')` represents a time duration of one month in NumPy.
# 4. The above calculation results in a floating-point value representing the months, but we want to convert it to integers.
# 5. We use `.astype(int, errors='ignore')` to convert the floating-point values to integers and ignore any errors.
# 6. The 'errors' parameter is set to 'ignore' to ensure any invalid conversion (e.g., NaT values) doesn't raise an error.

# %%
final_df['Months since installation'] = ((pd.to_datetime('today') - final_df['Date of Installation']) / np.timedelta64(1, 'M')).astype(int, errors='ignore')
final_df
# Out:
#       PM_Day  PM_Hour  PM_Month  Sensor  Sensor_reading  S.No   Serial No.  \
# 0         13        0        11  IITK01             NaN     1  81432131001
# 1         13        1        11  IITK01             NaN     1  81432131001
# 2         13        2        11  IITK01             NaN     1  81432131001
# 3         13        3        11  IITK01             NaN     1  81432131001
# 4         13        4        11  IITK01             NaN     1  81432131001
# ...      ...      ...       ...     ...             ...   ...          ...
# 9499      30       19        11  IITK25          120.25    23  81432147033
# 9500      30       20        11  IITK25          129.25    23  81432147033
# 9501      30       21        11  IITK25          131.00    23  81432147033
# 9502      30       22        11  IITK25          125.25    23  81432147033
# 9503      30       23        11  IITK25          136.75    23  81432147033
#
#                  Location  Latitude  Longitude Date of Installation  \
# 0         Transport Nagar  26.77917  80.885063           2021-12-13
# 1         Transport Nagar  26.77917  80.885063           2021-12-13
# 2         Transport Nagar  26.77917  80.885063           2021-12-13
# 3         Transport Nagar  26.77917  80.885063           2021-12-13
# 4         Transport Nagar  26.77917  80.885063           2021-12-13
# ...                   ...       ...        ...                  ...
# 9499  Kukrail_later_uppcb  26.90727  80.985200           2022-03-30
# 9500  Kukrail_later_uppcb  26.90727  80.985200           2022-03-30
# 9501  Kukrail_later_uppcb  26.90727  80.985200           2022-03-30
# 9502  Kukrail_later_uppcb  26.90727  80.985200           2022-03-30
# 9503  Kukrail_later_uppcb  26.90727  80.985200           2022-03-30
#
#       Months since installation
# 0                            19
# 1                            19
# 2                            19
# 3                            19
# 4                            19
# ...                         ...
# 9499                         15
# 9500                         15
# 9501                         15
# 9502                         15
# 9503                         15
#
# [9504 rows x 12 columns]

# %%
plt.scatter(final_df['Months since installation'], final_df['Sensor_reading'])
plt.xlabel('Months Since Installation')
plt.ylabel('sensor reading')
plt.show()

# %%
# final_df = final_df.drop(['Sensor','S.No','Serial No.', 'Location','Date of Installation','Months since installation'],axis = 1)
final_df = final_df.drop(['Sensor','S.No','Serial No.', 'Location','Date of Installation'],axis = 1)
final_df
# Out:
#       PM_Day  PM_Hour  PM_Month  Sensor_reading  Latitude  Longitude  \
# 0         13        0        11             NaN  26.77917  80.885063
# 1         13        1        11             NaN  26.77917  80.885063
# 2         13        2        11             NaN  26.77917  80.885063
# 3         13        3        11             NaN  26.77917  80.885063
# 4         13        4        11             NaN  26.77917  80.885063
# ...      ...      ...       ...             ...       ...        ...
# 9499      30       19        11          120.25  26.90727  80.985200
# 9500      30       20        11          129.25  26.90727  80.985200
# 9501      30       21        11          131.00  26.90727  80.985200
# 9502      30       22        11          125.25  26.90727  80.985200
# 9503      30       23        11          136.75  26.90727  80.985200
#
#       Months since installation
# 0                            19
# 1                            19
# 2                            19
# 3                            19
# 4                            19
# ...                         ...
# 9499                         15
# 9500                         15
# 9501                         15
# 9502                         15
# 9503                         15
#
# [9504 rows x 7 columns]

# %%
final_df = final_df.dropna(subset=['Sensor_reading'])
final_df
# Out:
#       PM_Day  PM_Hour  PM_Month  Sensor_reading   Latitude  Longitude  \
# 432       13        0        11           92.75  26.915201  80.942171
# 433       13        1        11           93.00  26.915201  80.942171
# 434       13        2        11           94.50  26.915201  80.942171
# 435       13        3        11           94.50  26.915201  80.942171
# 436       13        4        11           94.50  26.915201  80.942171
# ...      ...      ...       ...             ...        ...        ...
# 9499      30       19        11          120.25  26.907270  80.985200
# 9500      30       20        11          129.25  26.907270  80.985200
# 9501      30       21        11          131.00  26.907270  80.985200
# 9502      30       22        11          125.25  26.907270  80.985200
# 9503      30       23        11          136.75  26.907270  80.985200
#
#       Months since installation
# 432                          20
# 433                          20
# 434                          20
# 435                          20
# 436                          20
# ...                         ...
# 9499                         15
# 9500                         15
# 9501                         15
# 9502                         15
# 9503                         15
#
# [7260 rows x 7 columns]

# %%
sensor_data = final_df['Sensor_reading']
sensor_data
# Out:
# 432      92.75
# 433      93.00
# 434      94.50
# 435      94.50
# 436      94.50
#          ...
# 9499    120.25
# 9500    129.25
# 9501    131.00
# 9502    125.25
# 9503    136.75
# Name: Sensor_reading, Length: 7260, dtype: float64

# %%
final_df = final_df.drop('Sensor_reading', axis=1)
final_df
# Out:
#       PM_Day  PM_Hour  PM_Month   Latitude  Longitude  \
# 432       13        0        11  26.915201  80.942171
# 433       13        1        11  26.915201  80.942171
# 434       13        2        11  26.915201  80.942171
# 435       13        3        11  26.915201  80.942171
# 436       13        4        11  26.915201  80.942171
# ...      ...      ...       ...        ...        ...
# 9499      30       19        11  26.907270  80.985200
# 9500      30       20        11  26.907270  80.985200
# 9501      30       21        11  26.907270  80.985200
# 9502      30       22        11  26.907270  80.985200
# 9503      30       23        11  26.907270  80.985200
#
#       Months since installation
# 432                          20
# 433                          20
# 434                          20
# 435                          20
# 436                          20
# ...                         ...
# 9499                         15
# 9500                         15
# 9501                         15
# 9502                         15
# 9503                         15
#
# [7260 rows x 6 columns]

# %% [markdown]
# 1. We define a function named `create_and_drop_dummies` that takes a DataFrame (df) and the name of the column to process (column_name).
# 2. Inside the function, we create dummy variables using `pd.get_dummies` for the specified column_name, set the appropriate prefix, and concatenate them to the original DataFrame df.
# 3. We then drop the original `column_name` from the DataFrame to remove redundant information since it is now represented by the dummy variables.

# %%
def create_and_drop_dummies(df, column_name):
    dummies = pd.get_dummies(df[column_name], prefix=column_name)
    df = pd.concat([df, dummies], axis=1)
    df.drop([column_name], axis=1, inplace=True)
    return df

final_df = create_and_drop_dummies(final_df, 'PM_Day')
final_df = create_and_drop_dummies(final_df, 'PM_Hour')
final_df = create_and_drop_dummies(final_df, 'PM_Month')

final_df
# Out:
#        Latitude  Longitude  Months since installation  PM_Day_13  PM_Day_14  \
# 432   26.915201  80.942171                         20          1          0
# 433   26.915201  80.942171                         20          1          0
# 434   26.915201  80.942171                         20          1          0
# 435   26.915201  80.942171                         20          1          0
# 436   26.915201  80.942171                         20          1          0
# ...         ...        ...                        ...        ...        ...
# 9499  26.907270  80.985200                         15          0          0
# 9500  26.907270  80.985200                         15          0          0
# 9501  26.907270  80.985200                         15          0          0
# 9502  26.907270  80.985200                         15          0          0
# 9503  26.907270  80.985200                         15          0          0
#
#       PM_Day_15  PM_Day_16  PM_Day_17  PM_Day_18  PM_Day_19  ...  PM_Hour_15  \
# 432           0          0          0          0          0  ...           0
# 433           0          0          0          0          0  ...           0
# 434           0          0          0          0          0  ...           0
# 435           0          0          0          0          0  ...           0
# 436           0          0          0          0          0  ...           0
# ...         ...        ...        ...        ...        ...  ...         ...
# 9499          0          0          0          0          0  ...           0
# 9500          0          0          0          0          0  ...           0
# 9501          0          0          0          0          0  ...           0
# 9502          0          0          0          0          0  ...           0
# 9503          0          0          0          0          0  ...           0
#
#       PM_Hour_16  PM_Hour_17  PM_Hour_18  PM_Hour_19  PM_Hour_20  PM_Hour_21  \
# 432            0           0           0           0           0           0
# 433            0           0           0           0           0           0
# 434            0           0           0           0           0           0
# 435            0           0           0           0           0           0
# 436            0           0           0           0           0           0
# ...          ...         ...         ...         ...         ...         ...
# 9499           0           0           0           1           0           0
# 9500           0           0           0           0           1           0
# 9501           0           0           0           0           0           1
# 9502           0           0           0           0           0           0
# 9503           0           0           0           0           0           0
#
#       PM_Hour_22  PM_Hour_23  PM_Month_11
# 432            0           0            1
# 433            0           0            1
# 434            0           0            1
# 435            0           0            1
# 436            0           0            1
# ...          ...         ...          ...
# 9499           0           0            1
# 9500           0           0            1
# 9501           0           0            1
# 9502           1           0            1
# 9503           0           1            1
#
# [7260 rows x 46 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split( final_df,sensor_data, test_size=0.25, random_state=42)
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (5445, 46) (1815, 46) (5445,) (1815,)

# %%
# Scaling on the training and testing datasets. Used in ML to bring features to a similar range, which can lead to improved model performance.
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define the input shape of the model, 'input_shape' will be the number of features in the input data (X_train_scaled), here 46.
input_shape = X_train_scaled.shape[1]

# Define the model architecture
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(input_shape,))) # dense (fully connected) layer with 64 neurons and ReLU activation function.
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu')) # another dense layer with 32 neurons and ReLU activation function.
model.add(Dense(1, activation='linear')) # output layer with a single neuron and linear activation function.


# Compile the model
model.compile(optimizer='adam', loss='mean_absolute_error')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                3008
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 32)                1056
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 6,177
# Trainable params: 6,177
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 1. `epochs` specifies the number of times the entire training dataset will be passed through the model during training.
# 2. `batch_size` determines the number of samples that will be propagated through the network before the weights are updated.
# 3. `validation_split` is the proportion of training data that will be used for validation during training. For example, if set to 0.1, 10% of the training data will be used for validation, and the rest will be used for training.
# 4. `loss: x` : This is the training loss for the current epoch. The training loss is a measure of how well the model is performing on the training data. The value (x in this case) represents the mean absolute error (MAE) between the predicted values and the actual target values on the training data for that epoch. The goal is to minimize this loss during training.
# 5. `val_loss: y`: This is the validation loss for the current epoch. The validation loss is a measure of how well the model is performing on the validation data, which is a subset of the training data that was set aside for validation. The value (y in this case) represents the mean absolute error (MAE) on the validation data for that epoch. The purpose of validation is to monitor how well the model generalizes to unseen data and to detect overfitting. The goal is to minimize the validation loss as well.

# %%
# Train the model
history = model.fit(X_train_scaled, Y_train, epochs=200, batch_size=32, validation_split = 0.1)
# Out:
# Epoch 1/200
# 154/154 [==============================] - 0s 2ms/step - loss: 13.3430 - val_loss: 18.6042
# Epoch 2/200
# 154/154 [==============================] - 0s 2ms/step - loss: 13.2818 - val_loss: 18.7871
# Epoch 3/200
# 154/154 [==============================] - 0s 3ms/step - loss: 13.2339 - val_loss: 18.7308
# Epoch 4/200
# 154/154 [==============================] - 0s 2ms/step - loss: 13.1756 - val_loss: 18.6573
# Epoch 5/200
# 154/154 [==============================] - 0s 3ms/step - loss: 13.1635 - val_loss: 18.6381
# Epoch 6/200
# 154/154 [==============================] - 0s 2ms/step - loss: 12.9834 - val_loss: 18.9145
# Epoch 7/200
# 154/154 [==============================] - 0s 2ms/step - loss: 13.0420 - val_loss: 18.7968
# Epoch 8/200
# 154/154 [==============================] - 0s 2ms/step - loss: 13.0464 - val_loss: 18.5106
# Epoch 9/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.8977 - val_loss: 18.5253
# Epoch 10/200
# 154/154 [==============================] - 0s 2ms/step - loss: 12.8918 - val_loss: 18.3499
# Epoch 11/200
# 154/154 [==============================] - 0s 2ms/step - loss: 12.7642 - val_loss: 18.2499
# Epoch 12/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.7308 - val_loss: 18.5037
# Epoch 13/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.7175 - val_loss: 18.3100
# Epoch 14/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.5230 - val_loss: 18.3368
# Epoch 15/200
# 154/154 [==============================] - 0s 2ms/step - loss: 12.5241 - val_loss: 18.4459
# Epoch 16/200
# 154/154 [==============================] - 0s 2ms/step - loss: 12.4759 - val_loss: 18.2920
# Epoch 17/200
# 154/154 [==============================] - 0s 2ms/step - loss: 12.5132 - val_loss: 18.4508
# Epoch 18/200
# 154/154 [==============================] - 0s 3ms/step - loss: 12.4241 - val_loss: 18.1576
# Epoch 19/200
# 154/154 [==============================] - 0s 2ms/step - loss: 12.4503 - val_loss: 18.2288
# Epoch 20/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.3575 - val_loss: 18.1272
# Epoch 21/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.3400 - val_loss: 18.0501
# Epoch 22/200
# 154/154 [==============================] - 0s 2ms/step - loss: 12.2591 - val_loss: 18.3280
# Epoch 23/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.2869 - val_loss: 18.4529
# Epoch 24/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.2985 - val_loss: 17.8838
# Epoch 25/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.1742 - val_loss: 18.3854
# Epoch 26/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.2140 - val_loss: 18.3761
# Epoch 27/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.0960 - val_loss: 18.2320
# Epoch 28/200
# 154/154 [==============================] - 0s 1ms/step - loss: 12.0477 - val_loss: 18.0209
# Epoch 29/200
# 154/154 [==============================] - 0s 2ms/step - loss: 11.9653 - val_loss: 17.9165
# Epoch 30/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.9669 - val_loss: 18.6146
# Epoch 31/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.9233 - val_loss: 17.9732
# Epoch 32/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.8958 - val_loss: 17.9407
# Epoch 33/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.8069 - val_loss: 17.7747
# Epoch 34/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.7519 - val_loss: 17.8813
# Epoch 35/200
# 154/154 [==============================] - 0s 2ms/step - loss: 11.8893 - val_loss: 18.0021
# Epoch 36/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.9137 - val_loss: 17.8760
# Epoch 37/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.7167 - val_loss: 18.1039
# Epoch 38/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.6472 - val_loss: 18.0870
# Epoch 39/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.6537 - val_loss: 17.9847
# Epoch 40/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.6146 - val_loss: 18.0632
# Epoch 41/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.4951 - val_loss: 17.8943
# Epoch 42/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.5470 - val_loss: 17.9048
# Epoch 43/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.4966 - val_loss: 17.9159
# Epoch 44/200
# 154/154 [==============================] - 0s 2ms/step - loss: 11.4958 - val_loss: 17.7220
# Epoch 45/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.4569 - val_loss: 17.7825
# Epoch 46/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.4518 - val_loss: 17.9028
# Epoch 47/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.4288 - val_loss: 17.6605
# Epoch 48/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.4007 - val_loss: 17.6912
# Epoch 49/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.3823 - val_loss: 17.5869
# Epoch 50/200
# 154/154 [==============================] - 0s 2ms/step - loss: 11.3102 - val_loss: 17.5076
# Epoch 51/200
# 154/154 [==============================] - 0s 2ms/step - loss: 11.2415 - val_loss: 17.4519
# Epoch 52/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.2272 - val_loss: 17.5651
# Epoch 53/200
# 154/154 [==============================] - 0s 2ms/step - loss: 11.2663 - val_loss: 17.6674
# Epoch 54/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.2205 - val_loss: 17.4545
# Epoch 55/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.2460 - val_loss: 17.5694
# Epoch 56/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.2324 - val_loss: 17.3345
# Epoch 57/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.1327 - val_loss: 17.3771
# Epoch 58/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.0706 - val_loss: 17.6296
# Epoch 59/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.0955 - val_loss: 17.5374
# Epoch 60/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.0926 - val_loss: 17.8413
# Epoch 61/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.9937 - val_loss: 17.4618
# Epoch 62/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.9651 - val_loss: 17.5982
# Epoch 63/200
# 154/154 [==============================] - 0s 1ms/step - loss: 11.0086 - val_loss: 17.2727
# Epoch 64/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.9187 - val_loss: 17.3880
# Epoch 65/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.8610 - val_loss: 17.3501
# Epoch 66/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.8641 - val_loss: 17.2666
# Epoch 67/200
# 154/154 [==============================] - 0s 2ms/step - loss: 10.8091 - val_loss: 17.3968
# Epoch 68/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.7994 - val_loss: 17.4007
# Epoch 69/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.8648 - val_loss: 17.4681
# Epoch 70/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.7863 - val_loss: 17.3896
# Epoch 71/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.7941 - val_loss: 17.1605
# Epoch 72/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.7597 - val_loss: 17.5572
# Epoch 73/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.6409 - val_loss: 17.2252
# Epoch 74/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.6679 - val_loss: 17.3584
# Epoch 75/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.7459 - val_loss: 17.5921
# Epoch 76/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.6120 - val_loss: 17.2157
# Epoch 77/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.6663 - val_loss: 17.1432
# Epoch 78/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.5845 - val_loss: 17.3284
# Epoch 79/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.6086 - val_loss: 17.2178
# Epoch 80/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.5651 - val_loss: 17.4068
# Epoch 81/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.6060 - val_loss: 16.9762
# Epoch 82/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.5933 - val_loss: 17.1848
# Epoch 83/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.4466 - val_loss: 17.1641
# Epoch 84/200
# 154/154 [==============================] - 0s 2ms/step - loss: 10.4353 - val_loss: 17.4820
# Epoch 85/200
# 154/154 [==============================] - 0s 2ms/step - loss: 10.4713 - val_loss: 17.1687
# Epoch 86/200
# 154/154 [==============================] - 0s 2ms/step - loss: 10.3949 - val_loss: 17.4452
# Epoch 87/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.4257 - val_loss: 17.2482
# Epoch 88/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.4633 - val_loss: 17.2965
# Epoch 89/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.4532 - val_loss: 17.4736
# Epoch 90/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.3686 - val_loss: 17.3083
# Epoch 91/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.3683 - val_loss: 17.0704
# Epoch 92/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.2941 - val_loss: 17.0714
# Epoch 93/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.3204 - val_loss: 16.8555
# Epoch 94/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.3675 - val_loss: 17.2297
# Epoch 95/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.3531 - val_loss: 17.2101
# Epoch 96/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.3248 - val_loss: 17.0995
# Epoch 97/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.2776 - val_loss: 17.0640
# Epoch 98/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.3574 - val_loss: 16.9013
# Epoch 99/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.2450 - val_loss: 16.9946
# Epoch 100/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.2902 - val_loss: 17.1289
# Epoch 101/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.2719 - val_loss: 17.1253
# Epoch 102/200
# 154/154 [==============================] - 0s 2ms/step - loss: 10.2324 - val_loss: 17.0522
# Epoch 103/200
# 154/154 [==============================] - 0s 2ms/step - loss: 10.3228 - val_loss: 17.1598
# Epoch 104/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.2266 - val_loss: 16.9342
# Epoch 105/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.1697 - val_loss: 17.1708
# Epoch 106/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.1578 - val_loss: 16.9023
# Epoch 107/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.0886 - val_loss: 17.1853
# Epoch 108/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.1623 - val_loss: 17.0244
# Epoch 109/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.1512 - val_loss: 17.0366
# Epoch 110/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.0674 - val_loss: 17.0937
# Epoch 111/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.1044 - val_loss: 17.1034
# Epoch 112/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.0179 - val_loss: 17.2841
# Epoch 113/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.0522 - val_loss: 17.2484
# Epoch 114/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.0119 - val_loss: 17.0570
# Epoch 115/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.0615 - val_loss: 17.0686
# Epoch 116/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.9855 - val_loss: 16.9761
# Epoch 117/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.0569 - val_loss: 17.1247
# Epoch 118/200
# 154/154 [==============================] - 0s 1ms/step - loss: 10.0438 - val_loss: 16.9275
# Epoch 119/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.8616 - val_loss: 17.1713
# Epoch 120/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.9181 - val_loss: 17.2020
# Epoch 121/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.9011 - val_loss: 16.8626
# Epoch 122/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.9468 - val_loss: 17.0160
# Epoch 123/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.8611 - val_loss: 16.9388
# Epoch 124/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.8816 - val_loss: 16.8584
# Epoch 125/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.8511 - val_loss: 17.0135
# Epoch 126/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.8725 - val_loss: 17.1214
# Epoch 127/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.9148 - val_loss: 16.8613
# Epoch 128/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.9927 - val_loss: 16.9877
# Epoch 129/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.8639 - val_loss: 17.1198
# Epoch 130/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.8429 - val_loss: 17.1335
# Epoch 131/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.7826 - val_loss: 17.2215
# Epoch 132/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.7994 - val_loss: 17.1790
# Epoch 133/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.8133 - val_loss: 17.0115
# Epoch 134/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.8242 - val_loss: 16.9852
# Epoch 135/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.7721 - val_loss: 16.9581
# Epoch 136/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.7764 - val_loss: 17.1817
# Epoch 137/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.8635 - val_loss: 17.0176
# Epoch 138/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.7510 - val_loss: 17.1102
# Epoch 139/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.8169 - val_loss: 16.8851
# Epoch 140/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.6914 - val_loss: 16.8018
# Epoch 141/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.6262 - val_loss: 17.1053
# Epoch 142/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.6373 - val_loss: 17.1507
# Epoch 143/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.7077 - val_loss: 16.6718
# Epoch 144/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.6166 - val_loss: 17.1076
# Epoch 145/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.6775 - val_loss: 16.9433
# Epoch 146/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.6112 - val_loss: 17.1381
# Epoch 147/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.5960 - val_loss: 16.9428
# Epoch 148/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.5894 - val_loss: 16.7976
# Epoch 149/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.5457 - val_loss: 16.9081
# Epoch 150/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.4979 - val_loss: 16.7282
# Epoch 151/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.5966 - val_loss: 17.0299
# Epoch 152/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.4721 - val_loss: 16.7996
# Epoch 153/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.5248 - val_loss: 16.9114
# Epoch 154/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.6419 - val_loss: 16.7996
# Epoch 155/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.5410 - val_loss: 16.8785
# Epoch 156/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.5628 - val_loss: 16.8969
# Epoch 157/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.5220 - val_loss: 16.9369
# Epoch 158/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.5499 - val_loss: 17.0966
# Epoch 159/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.4842 - val_loss: 16.8699
# Epoch 160/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.3944 - val_loss: 16.9678
# Epoch 161/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.4808 - val_loss: 17.1261
# Epoch 162/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.4392 - val_loss: 16.9193
# Epoch 163/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.4278 - val_loss: 17.1901
# Epoch 164/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.4597 - val_loss: 17.0388
# Epoch 165/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.4736 - val_loss: 16.9374
# Epoch 166/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.3763 - val_loss: 17.2713
# Epoch 167/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.3689 - val_loss: 17.0446
# Epoch 168/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.2678 - val_loss: 16.9630
# Epoch 169/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.4111 - val_loss: 17.1394
# Epoch 170/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.3499 - val_loss: 17.0820
# Epoch 171/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.2866 - val_loss: 17.0380
# Epoch 172/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.3500 - val_loss: 17.1416
# Epoch 173/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.3997 - val_loss: 17.1885
# Epoch 174/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.2255 - val_loss: 17.0839
# Epoch 175/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.2849 - val_loss: 17.1376
# Epoch 176/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.2741 - val_loss: 17.0716
# Epoch 177/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.3230 - val_loss: 17.0752
# Epoch 178/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.2952 - val_loss: 17.2893
# Epoch 179/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.3150 - val_loss: 17.3306
# Epoch 180/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.3166 - val_loss: 16.8250
# Epoch 181/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.3281 - val_loss: 17.0770
# Epoch 182/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.2464 - val_loss: 17.0463
# Epoch 183/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.2518 - val_loss: 17.2382
# Epoch 184/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1977 - val_loss: 17.0864
# Epoch 185/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.3736 - val_loss: 17.1281
# Epoch 186/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1643 - val_loss: 17.0549
# Epoch 187/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1955 - val_loss: 17.1549
# Epoch 188/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.2936 - val_loss: 16.8150
# Epoch 189/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1078 - val_loss: 17.1741
# Epoch 190/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1270 - val_loss: 16.8934
# Epoch 191/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1717 - val_loss: 17.1533
# Epoch 192/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1432 - val_loss: 16.8605
# Epoch 193/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.1182 - val_loss: 17.3061
# Epoch 194/200
# 154/154 [==============================] - 0s 2ms/step - loss: 9.1514 - val_loss: 17.3897
# Epoch 195/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1885 - val_loss: 17.1075
# Epoch 196/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.0913 - val_loss: 17.2097
# Epoch 197/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1577 - val_loss: 16.9922
# Epoch 198/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1159 - val_loss: 17.0506
# Epoch 199/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.1113 - val_loss: 16.6986
# Epoch 200/200
# 154/154 [==============================] - 0s 1ms/step - loss: 9.0594 - val_loss: 17.1872

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'bo', label='Training loss') # Plotting the training loss as blue circles 'bo'.
plt.plot(epochs, val_loss, 'b', label='Validation loss') # Plotting the validation loss as a solid blue line 'b'.
plt.title('Training and validation loss trend')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Ideally, we want to see both the training and validation loss decrease over epochs, indicating that the model is learning and generalizing well. If the training loss continues to decrease while the validation loss starts to increase or stabilize, it could be an indication of overfitting, where the model is becoming too specific to the training data and not generalizing well to new data.

# %%
# Evaluate the model on the test set
test_loss = model.evaluate(X_test_scaled, Y_test)
# Out:
#  1/57 [..............................] - ETA: 1s - loss: 14.1163
# 57/57 [==============================] - 0s 2ms/step - loss: 15.4096

# %%
y_pred = model.predict(X_test_scaled)
y_pred
# Out:
# 57/57 [==============================] - 0s 1ms/step
# array([[ 72.53324],
#        [158.73549],
#        [376.7955 ],
#        ...,
#        [149.7689 ],
#        [261.2517 ],
#        [149.30328]], dtype=float32)

# %%
# Using `ravel()` to flatten the 2D array into a 1D array.
y_pred = y_pred.ravel()
y_pred
# Out:
# array([ 72.53324, 158.73549, 376.7955 , ..., 149.7689 , 261.2517 ,
#        149.30328], dtype=float32)

# %%
Y_test
# Out:
# 5652     69.75
# 4471    195.25
# 7733    342.00
# 3239     78.50
# 4117     27.50
#          ...
# 1805     58.50
# 1883     50.25
# 8934    132.25
# 8624    188.75
# 8190    157.25
# Name: Sensor_reading, Length: 1815, dtype: float64

# %% [markdown]
# 1. R-squared (R2) score is a common metric for evaluating the performance of regression models.
# 2. It is a value between 0 and 1, where 1 represents a perfect fit of the model to the data, and values closer to 0 indicate a poor fit.
# 3. A higher R2 score indicates a better fit of the model to the data, while a lower R2 score suggests that the model may not be effectively capturing the patterns in the data.

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,Y_test)
# Out:
# 0.7836090312784414

# %%
plt.scatter(y_pred, Y_test)
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.show()

# %%
# Create a dataframe with the predicted and actual values
df = pd.DataFrame({'y_pred': y_pred, 'y_test': Y_test})

# Compute the correlation matrix
corr = df.corr()

# Create a heatmap of the correlation matrix using seaborn
sns.heatmap(corr, annot=True, cmap='coolwarm')

# Set the title and display the plot
plt.title('Correlation between y_pred and y_test')
plt.show()

# %%
corr
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.895488
# y_test  0.895488  1.000000

# %% [markdown]
# The heatmap visualizes the correlation between the predicted and actual values. The values in the heatmap range from -1 to 1, where -1 indicates a perfect negative correlation, 1 indicates a perfect positive correlation, and 0 indicates no correlation. The color scale ('coolwarm' in this case) represents the magnitude and direction of the correlation.
#
# By analyzing the heatmap, you can gain insights into how well the predicted values (y_pred) correlate with the actual target values (y_test). A strong positive correlation (close to 1) indicates that the model's predictions align well with the true target values, while a weak or negative correlation may indicate that the model's predictions are less accurate.

# %%
# create a linear regression object and fit the model to the training data
model = LinearRegression()
model.fit(X_train_scaled, Y_train)

# predict on the test data
y_pred = model.predict(X_test_scaled)

# calculate the mean squared error
mse = mean_absolute_error(Y_test, y_pred)
print('Mean Absolute Error:', mse)

print('Model Accuracy:', model.score(X_test_scaled, Y_test))
# Out:
# Mean Absolute Error: 23.97993871216091
# Model Accuracy: 0.5970919087088863
